# %%
# Inpsired by - https://github.com/mrocklin/arxiv-matplotlib
# Released with BSD-3-Clause license - https://opensource.org/license/bsd-3-clause


# %matplotlib inline

# %%
from google.cloud import storage
import coiled

# set key credentials file path
# import os
# os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = 'C:\\Users\\\USERNAME_GOES_HERE\\AppData\\Roaming\\gcloud\\application_default_credentials.json'

# define function that list files in the bucket
def list_cs_files(bucket_name, path, limit=1000): 
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    print("Bucket is: "+str(bucket))

    blobs = bucket.list_blobs(prefix=path, max_results=limit)

    file_list = [file.name for file in blobs]

    return file_list

# Path - 'gs://arxiv-dataset/arxiv/' -  gs://<bucket_name>/<file_path_inside_bucket>.

file_list = list_cs_files('arxiv-dataset', 'arxiv', limit=1000)
pdf_files = [filename for filename in file_list if filename.endswith(".pdf")]
print(pdf_files[:10])
print("Length of PDF List: "+str(len(pdf_files)))
# Out:
# Bucket is: <Bucket: arxiv-dataset>
# ['arxiv/acc-phys/pdf/9411/9411001v1.pdf', 'arxiv/acc-phys/pdf/9411/9411002v1.pdf', 'arxiv/acc-phys/pdf/9411/9411003v1.pdf', 'arxiv/acc-phys/pdf/9411/9411004v1.pdf', 'arxiv/acc-phys/pdf/9502/9502001v1.pdf', 'arxiv/acc-phys/pdf/9502/9502002v1.pdf', 'arxiv/acc-phys/pdf/9503/9503001v2.pdf', 'arxiv/acc-phys/pdf/9503/9503002v1.pdf', 'arxiv/acc-phys/pdf/9503/9503003v1.pdf', 'arxiv/acc-phys/pdf/9503/9503004v1.pdf']
# Length of PDF List: 377

# %%
# %%time
def extract(file_set):
    """ Extract and process one directory of arXiv data
    
    Returns
    -------
    filename: str
    contains_matplotlib: boolean
    """
    out = []
    
    # Create a connection per file_set
    storage_client = storage.Client()
    bucket = storage_client.bucket('arxiv-dataset')

    for filename in file_set:

        """Read the content of a PDF file from Google Cloud Storage."""
        # client = storage.Client()
        # bucket = client.bucket(bucket_name)
        blob = bucket.blob(filename)

        try:
            # Download the PDF content as bytes
            pdf_bytes = blob.download_as_bytes()
        except Exception as e:
            print(f"Error reading PDF: {str(e)}")
        
        out.append((
            filename, 
            b"matplotlib" in pdf_bytes.lower()
        ))

    return out

out = extract(pdf_files[0:10])
print(out)
# Out:
# [('arxiv/acc-phys/pdf/9411/9411001v1.pdf', False), ('arxiv/acc-phys/pdf/9411/9411002v1.pdf', False), ('arxiv/acc-phys/pdf/9411/9411003v1.pdf', False), ('arxiv/acc-phys/pdf/9411/9411004v1.pdf', False), ('arxiv/acc-phys/pdf/9502/9502001v1.pdf', False), ('arxiv/acc-phys/pdf/9502/9502002v1.pdf', False), ('arxiv/acc-phys/pdf/9503/9503001v2.pdf', False), ('arxiv/acc-phys/pdf/9503/9503002v1.pdf', False), ('arxiv/acc-phys/pdf/9503/9503003v1.pdf', False), ('arxiv/acc-phys/pdf/9503/9503004v1.pdf', False)]
# CPU times: total: 15.6 ms
# Wall time: 3.5 s

# %%
chunk_size = 10
chunked_list = [pdf_files[i:i + chunk_size] for i in range(0, len(pdf_files), chunk_size)]
print(chunked_list[0])
print("Number of chunks: "+str(len(chunked_list)))
# Out:
# ['arxiv/acc-phys/pdf/9411/9411001v1.pdf', 'arxiv/acc-phys/pdf/9411/9411002v1.pdf', 'arxiv/acc-phys/pdf/9411/9411003v1.pdf', 'arxiv/acc-phys/pdf/9411/9411004v1.pdf', 'arxiv/acc-phys/pdf/9502/9502001v1.pdf', 'arxiv/acc-phys/pdf/9502/9502002v1.pdf', 'arxiv/acc-phys/pdf/9503/9503001v2.pdf', 'arxiv/acc-phys/pdf/9503/9503002v1.pdf', 'arxiv/acc-phys/pdf/9503/9503003v1.pdf', 'arxiv/acc-phys/pdf/9503/9503004v1.pdf']
# Number of chunks: 38

# %%
# %%time
cluster = coiled.Cluster(
    n_workers=5,
    name="arxiv",
    package_sync=True, 
    backend_options={"region": "us-east1"},  # faster and cheaper
)
from dask.distributed import Client, wait
# Note for client to work in Jupyter, it needs to be updated to use Dask as shown here
client = Client(cluster)
# Out:
# Output()
# ---Egg to wheel conversion Log for vboxapi---
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Package - h5py, The 'h5py' PyPI package is not portable, and will not work on a cluster
# Install h5py using `conda install -c conda-forge h5py`
# Package - mysqlclient, The 'mysqlclient' PyPI package is not portable, and will not work on a cluster
# Install mysqlclient using `conda install -c conda-forge mysqlclient`
# Package - opencv-python, The 'opencv-python' PyPI package is not portable, and will not work on a cluster
# Install opencv-python using `conda install -c conda-forge opencv`
# Package - tensorflow-intel, The 'tensorflow-intel' PyPI package is Windows-only, and will not work on a cluster
# Install the standard tensorflow version using `pip install tensorflow` or `conda install -conda-forge tensorflow`
# Package - vboxapi, Failed to convert the package egg to a wheel, will not be included in environment, check stdout
# for egg conversion log
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭────────────────────────────────────────── Package Info ──────────────────────────────────────────╮
# │                                                      ╷                                           │
# │   Package                                            │ Note                                      │
# │ ╶────────────────────────────────────────────────────┼─────────────────────────────────────────╴ │
# │   APScheduler                                        │ https://pypi.org/simple                   │
# │   Babel                                              │ https://pypi.org/simple                   │
# │   Backtesting                                        │ https://pypi.org/simple                   │
# │   Bootstrap-Flask                                    │ https://pypi.org/simple                   │
# │   Brotli                                             │ https://pypi.org/simple                   │
# │   CairoSVG                                           │ https://pypi.org/simple                   │
# │   Deprecated                                         │ https://pypi.org/simple                   │
# │   Flask                                              │ https://pypi.org/simple                   │
# │   Flask-BabelEx                                      │ https://pypi.org/simple                   │
# │   Flask-Login                                        │ https://pypi.org/simple                   │
# │   Flask-Mail                                         │ https://pypi.org/simple                   │
# │   Flask-Migrate                                      │ https://pypi.org/simple                   │
# │   Flask-Principal                                    │ https://pypi.org/simple                   │
# │   Flask-SQLAlchemy                                   │ https://pypi.org/simple                   │
# │   Flask-Security-Too                                 │ https://pypi.org/simple                   │
# │   Flask-SocketIO                                     │ https://pypi.org/simple                   │
# │   Flask-WTF                                          │ https://pypi.org/simple                   │
# │   GitPython                                          │ https://pypi.org/simple                   │
# │   HeapDict                                           │ https://pypi.org/simple                   │
# │   Jinja2                                             │ https://pypi.org/simple                   │
# │   Mako                                               │ https://pypi.org/simple                   │
# │   Markdown                                           │ https://pypi.org/simple                   │
# │   MarkupSafe                                         │ https://pypi.org/simple                   │
# │   Pillow                                             │ https://pypi.org/simple                   │
# │   PyJWT                                              │ https://pypi.org/simple                   │
# │   PyNaCl                                             │ https://pypi.org/simple                   │
# │   PyPrind                                            │ https://pypi.org/simple                   │
# │   PyWavelets                                         │ https://pypi.org/simple                   │
# │   PyYAML                                             │ https://pypi.org/simple                   │
# │   Pygments                                           │ https://pypi.org/simple                   │
# │   Pympler                                            │ https://pypi.org/simple                   │
# │   QtPy                                               │ https://pypi.org/simple                   │
# │   SQLAlchemy                                         │ https://pypi.org/simple                   │
# │   SQLAlchemy-Utils                                   │ https://pypi.org/simple                   │
# │   Send2Trash                                         │ https://pypi.org/simple                   │
# │   Sphinx                                             │ https://pypi.org/simple                   │
# │   WTForms                                            │ https://pypi.org/simple                   │
# │   Werkzeug                                           │ https://pypi.org/simple                   │
# │   absl-py                                            │ https://pypi.org/simple                   │
# │   accelerate                                         │ https://pypi.org/simple                   │
# │   aiobotocore                                        │ https://pypi.org/simple                   │
# │   aiofiles                                           │ https://pypi.org/simple                   │
# │   aiohttp                                            │ https://pypi.org/simple                   │
# │   aiohttp-retry                                      │ https://pypi.org/simple                   │
# │   aioitertools                                       │ https://pypi.org/simple                   │
# │   aiosignal                                          │ https://pypi.org/simple                   │
# │   alabaster                                          │ https://pypi.org/simple                   │
# │   albumentations                                     │ https://pypi.org/simple                   │
# │   alembic                                            │ https://pypi.org/simple                   │
# │   altair                                             │ https://pypi.org/simple                   │
# │   annotated-types                                    │ https://pypi.org/simple                   │
# │   anyio                                              │ https://pypi.org/simple                   │
# │   appdirs                                            │ https://pypi.org/simple                   │
# │   argcomplete                                        │ https://pypi.org/simple                   │
# │   argon2-cffi                                        │ https://pypi.org/simple                   │
# │   argon2-cffi-bindings                               │ https://pypi.org/simple                   │
# │   arrow                                              │ https://pypi.org/simple                   │
# │   asn1crypto                                         │ https://pypi.org/simple                   │
# │   asttokens                                          │ https://pypi.org/simple                   │
# │   astunparse                                         │ https://pypi.org/simple                   │
# │   async-timeout                                      │ https://pypi.org/simple                   │
# │   attrs                                              │ https://pypi.org/simple                   │
# │   backcall                                           │ https://pypi.org/simple                   │
# │   backoff                                            │ https://pypi.org/simple                   │
# │   bcrypt                                             │ https://pypi.org/simple                   │
# │   beautifulsoup4                                     │ https://pypi.org/simple                   │
# │   bidict                                             │ https://pypi.org/simple                   │
# │   bleach                                             │ https://pypi.org/simple                   │
# │   blinker                                            │ https://pypi.org/simple                   │
# │   bokeh                                              │ https://pypi.org/simple                   │
# │   boto3                                              │ https://pypi.org/simple                   │
# │   botocore                                           │ https://pypi.org/simple                   │
# │   bt                                                 │ https://pypi.org/simple                   │
# │   cachetools                                         │ https://pypi.org/simple                   │
# │   cairocffi                                          │ https://pypi.org/simple                   │
# │   cattrs                                             │ https://pypi.org/simple                   │
# │   cbor2                                              │ https://pypi.org/simple                   │
# │   certifi                                            │ https://pypi.org/simple                   │
# │   cffi                                               │ https://pypi.org/simple                   │
# │   charset-normalizer                                 │ https://pypi.org/simple                   │
# │   click                                              │ https://pypi.org/simple                   │
# │   cloudpickle                                        │ https://pypi.org/simple                   │
# │   cmake                                              │ https://pypi.org/simple                   │
# │   coiled                                             │ https://pypi.org/simple                   │
# │   colorama                                           │ https://pypi.org/simple                   │
# │   comm                                               │ https://pypi.org/simple                   │
# │   contourpy                                          │ https://pypi.org/simple                   │
# │   cryptography                                       │ https://pypi.org/simple                   │
# │   cssselect2                                         │ https://pypi.org/simple                   │
# │   cycler                                             │ https://pypi.org/simple                   │
# │   dacite                                             │ https://pypi.org/simple                   │
# │   dask                                               │ https://pypi.org/simple                   │
# │   debugpy                                            │ https://pypi.org/simple                   │
# │   decorator                                          │ https://pypi.org/simple                   │
# │   defusedxml                                         │ https://pypi.org/simple                   │
# │   diffusers                                          │ https://pypi.org/simple                   │
# │   dill                                               │ https://pypi.org/simple                   │
# │   discord                                            │ https://pypi.org/simple                   │
# │   discord-py-interactions                            │ https://pypi.org/simple                   │
# │   discord-typings                                    │ https://pypi.org/simple                   │
# │   discord.py                                         │ https://pypi.org/simple                   │
# │   distributed                                        │ https://pypi.org/simple                   │
# │   dnspython                                          │ https://pypi.org/simple                   │
# │   docutils                                           │ https://pypi.org/simple                   │
# │   einops                                             │ https://pypi.org/simple                   │
# │   email-validator                                    │ https://pypi.org/simple                   │
# │   emoji                                              │ https://pypi.org/simple                   │
# │   entrypoints                                        │ https://pypi.org/simple                   │
# │   esbonio                                            │ https://pypi.org/simple                   │
# │   et-xmlfile                                         │ https://pypi.org/simple                   │
# │   executing                                          │ https://pypi.org/simple                   │
# │   expecttest                                         │ https://pypi.org/simple                   │
# │   extra-streamlit-components                         │ https://pypi.org/simple                   │
# │   fastapi                                            │ https://pypi.org/simple                   │
# │   fastjsonschema                                     │ https://pypi.org/simple                   │
# │   ffmpy                                              │ https://pypi.org/simple                   │
# │   ffn                                                │ https://pypi.org/simple                   │
# │   fiftyone                                           │ https://pypi.org/simple                   │
# │   fiftyone-brain                                     │ https://pypi.org/simple                   │
# │   fiftyone-db                                        │ https://pypi.org/simple                   │
# │   filelock                                           │ https://pypi.org/simple                   │
# │   flask-babel                                        │ https://pypi.org/simple                   │
# │   flask-mailman                                      │ https://pypi.org/simple                   │
# │   flatbuffers                                        │ https://pypi.org/simple                   │
# │   fonttools                                          │ https://pypi.org/simple                   │
# │   fqdn                                               │ https://pypi.org/simple                   │
# │   frozendict                                         │ https://pypi.org/simple                   │
# │   frozenlist                                         │ https://pypi.org/simple                   │
# │   fsspec                                             │ https://pypi.org/simple                   │
# │   ftfy                                               │ https://pypi.org/simple                   │
# │   funcy                                              │ https://pypi.org/simple                   │
# │   future                                             │ https://pypi.org/simple                   │
# │   gast                                               │ https://pypi.org/simple                   │
# │   geographiclib                                      │ https://pypi.org/simple                   │
# │   geopy                                              │ https://pypi.org/simple                   │
# │   gitdb                                              │ https://pypi.org/simple                   │
# │   glob2                                              │ https://pypi.org/simple                   │
# │   google-api-core                                    │ https://pypi.org/simple                   │
# │   google-auth                                        │ https://pypi.org/simple                   │
# │   google-auth-oauthlib                               │ https://pypi.org/simple                   │
# │   google-cloud                                       │ https://pypi.org/simple                   │
# │   google-cloud-core                                  │ https://pypi.org/simple                   │
# │   google-cloud-storage                               │ https://pypi.org/simple                   │
# │   google-cloud-vision                                │ https://pypi.org/simple                   │
# │   google-crc32c                                      │ https://pypi.org/simple                   │
# │   google-pasta                                       │ https://pypi.org/simple                   │
# │   google-resumable-media                             │ https://pypi.org/simple                   │
# │   googleapis-common-protos                           │ https://pypi.org/simple                   │
# │   googlemaps                                         │ https://pypi.org/simple                   │
# │   gradio                                             │ https://pypi.org/simple                   │
# │   graphql-core                                       │ https://pypi.org/simple                   │
# │   greenlet                                           │ https://pypi.org/simple                   │
# │   grpcio                                             │ https://pypi.org/simple                   │
# │   grpcio-status                                      │ https://pypi.org/simple                   │
# │   h11                                                │ https://pypi.org/simple                   │
# │   h2                                                 │ https://pypi.org/simple                   │
# │   hmmlearn                                           │ https://pypi.org/simple                   │
# │   hpack                                              │ https://pypi.org/simple                   │
# │   html5lib                                           │ https://pypi.org/simple                   │
# │   httpcore                                           │ https://pypi.org/simple                   │
# │   httpx                                              │ https://pypi.org/simple                   │
# │   huggingface-hub                                    │ https://pypi.org/simple                   │
# │   hypercorn                                          │ https://pypi.org/simple                   │
# │   hyperframe                                         │ https://pypi.org/simple                   │
# │   hypothesis                                         │ https://pypi.org/simple                   │
# │   idna                                               │ https://pypi.org/simple                   │
# │   imageio                                            │ https://pypi.org/simple                   │
# │   imagesize                                          │ https://pypi.org/simple                   │
# │   importlib-metadata                                 │ https://pypi.org/simple                   │
# │   importlib-resources                                │ https://pypi.org/simple                   │
# │   inflate64                                          │ https://pypi.org/simple                   │
# │   iniconfig                                          │ https://pypi.org/simple                   │
# │   ipykernel                                          │ https://pypi.org/simple                   │
# │   ipython                                            │ https://pypi.org/simple                   │
# │   ipython-genutils                                   │ https://pypi.org/simple                   │
# │   ipywidgets                                         │ https://pypi.org/simple                   │
# │   isoduration                                        │ https://pypi.org/simple                   │
# │   itsdangerous                                       │ https://pypi.org/simple                   │
# │   jax                                                │ https://pypi.org/simple                   │
# │   jedi                                               │ https://pypi.org/simple                   │
# │   jmespath                                           │ https://pypi.org/simple                   │
# │   joblib                                             │ https://pypi.org/simple                   │
# │   jsondiff                                           │ https://pypi.org/simple                   │
# │   jsonlines                                          │ https://pypi.org/simple                   │
# │   jsonpointer                                        │ https://pypi.org/simple                   │
# │   jsonschema                                         │ https://pypi.org/simple                   │
# │   jupyter                                            │ https://pypi.org/simple                   │
# │   jupyter-console                                    │ https://pypi.org/simple                   │
# │   jupyter-events                                     │ https://pypi.org/simple                   │
# │   jupyter_client                                     │ https://pypi.org/simple                   │
# │   jupyter_core                                       │ https://pypi.org/simple                   │
# │   jupyter_server                                     │ https://pypi.org/simple                   │
# │   jupyter_server_terminals                           │ https://pypi.org/simple                   │
# │   jupyterlab-pygments                                │ https://pypi.org/simple                   │
# │   jupyterlab-widgets                                 │ https://pypi.org/simple                   │
# │   kaleido                                            │ https://pypi.org/simple                   │
# │   keras                                              │ https://pypi.org/simple                   │
# │   keyring                                            │ https://pypi.org/simple                   │
# │   kiwisolver                                         │ https://pypi.org/simple                   │
# │   lazy_loader                                        │ https://pypi.org/simple                   │
# │   libclang                                           │ https://pypi.org/simple                   │
# │   linkify-it-py                                      │ https://pypi.org/simple                   │
# │   locket                                             │ https://pypi.org/simple                   │
# │   loguru                                             │ https://pypi.org/simple                   │
# │   lsprotocol                                         │ https://pypi.org/simple                   │
# │   lxml                                               │ https://pypi.org/simple                   │
# │   markdown-it-py                                     │ https://pypi.org/simple                   │
# │   matplotlib-inline                                  │ https://pypi.org/simple                   │
# │   mdit-py-plugins                                    │ https://pypi.org/simple                   │
# │   mdurl                                              │ https://pypi.org/simple                   │
# │   mistune                                            │ https://pypi.org/simple                   │
# │   mkl                                                │ https://pypi.org/simple                   │
# │   mkl-include                                        │ https://pypi.org/simple                   │
# │   ml-dtypes                                          │ https://pypi.org/simple                   │
# │   mongoengine                                        │ https://pypi.org/simple                   │
# │   motor                                              │ https://pypi.org/simple                   │
# │   mpl-interactions                                   │ https://pypi.org/simple                   │
# │   mpmath                                             │ https://pypi.org/simple                   │
# │   msgpack                                            │ https://pypi.org/simple                   │
# │   multidict                                          │ https://pypi.org/simple                   │
# │   multitasking                                       │ https://pypi.org/simple                   │
# │   multivolumefile                                    │ https://pypi.org/simple                   │
# │   mypy-extensions                                    │ https://pypi.org/simple                   │
# │   mysql-connector-python                             │ https://pypi.org/simple                   │
# │   nbclassic                                          │ https://pypi.org/simple                   │
# │   nbclient                                           │ https://pypi.org/simple                   │
# │   nbconvert                                          │ https://pypi.org/simple                   │
# │   nbformat                                           │ https://pypi.org/simple                   │
# │   nest-asyncio                                       │ https://pypi.org/simple                   │
# │   networkx                                           │ https://pypi.org/simple                   │
# │   notebook                                           │ https://pypi.org/simple                   │
# │   notebook_shim                                      │ https://pypi.org/simple                   │
# │   numpy                                              │ https://pypi.org/simple                   │
# │   oauthlib                                           │ https://pypi.org/simple                   │
# │   openai                                             │ https://pypi.org/simple                   │
# │   opencv-python-headless                             │ https://pypi.org/simple                   │
# │   openpyxl                                           │ https://pypi.org/simple                   │
# │   opt-einsum                                         │ https://pypi.org/simple                   │
# │   orjson                                             │ https://pypi.org/simple                   │
# │   packaging                                          │ https://pypi.org/simple                   │
# │   pandas                                             │ https://pypi.org/simple                   │
# │   pandas-datareader                                  │ https://pypi.org/simple                   │
# │   pandocfilters                                      │ https://pypi.org/simple                   │
# │   paramiko                                           │ https://pypi.org/simple                   │
# │   parso                                              │ https://pypi.org/simple                   │
# │   partd                                              │ https://pypi.org/simple                   │
# │   passlib                                            │ https://pypi.org/simple                   │
# │   peewee                                             │ https://pypi.org/simple                   │
# │   phonenumberslite                                   │ https://pypi.org/simple                   │
# │   pickleshare                                        │ https://pypi.org/simple                   │
# │   pip                                                │ https://pypi.org/simple                   │
# │   platformdirs                                       │ https://pypi.org/simple                   │
# │   plotly                                             │ https://pypi.org/simple                   │
# │   pluggy                                             │ https://pypi.org/simple                   │
# │   pprintpp                                           │ https://pypi.org/simple                   │
# │   priority                                           │ https://pypi.org/simple                   │
# │   prometheus-client                                  │ https://pypi.org/simple                   │
# │   prompt-toolkit                                     │ https://pypi.org/simple                   │
# │   proto-plus                                         │ https://pypi.org/simple                   │
# │   protobuf                                           │ https://pypi.org/simple                   │
# │   psutil                                             │ https://pypi.org/simple                   │
# │   pure-eval                                          │ https://pypi.org/simple                   │
# │   py7zr                                              │ https://pypi.org/simple                   │
# │   pyOpenSSL                                          │ https://pypi.org/simple                   │
# │   pyarrow                                            │ https://pypi.org/simple                   │
# │   pyasn1                                             │ https://pypi.org/simple                   │
# │   pyasn1-modules                                     │ https://pypi.org/simple                   │
# │   pybcj                                              │ https://pypi.org/simple                   │
# │   pycparser                                          │ https://pypi.org/simple                   │
# │   pycryptodome                                       │ https://pypi.org/simple                   │
# │   pycryptodomex                                      │ https://pypi.org/simple                   │
# │   pydantic                                           │ https://pypi.org/simple                   │
# │   pydantic_core                                      │ https://pypi.org/simple                   │
# │   pydeck                                             │ https://pypi.org/simple                   │
# │   pydot                                              │ https://pypi.org/simple                   │
# │   pydub                                              │ https://pypi.org/simple                   │
# │   pygls                                              │ https://pypi.org/simple                   │
# │   pymongo                                            │ https://pypi.org/simple                   │
# │   pyodide-py                                         │ https://pypi.org/simple                   │
# │   pyparsing                                          │ https://pypi.org/simple                   │
# │   pypng                                              │ https://pypi.org/simple                   │
# │   pyppmd                                             │ https://pypi.org/simple                   │
# │   pyre-extensions                                    │ https://pypi.org/simple                   │
# │   pyrsistent                                         │ https://pypi.org/simple                   │
# │   pyserial                                           │ https://pypi.org/simple                   │
# │   pysftp                                             │ https://pypi.org/simple                   │
# │   pyspellchecker                                     │ https://pypi.org/simple                   │
# │   pytest                                             │ https://pypi.org/simple                   │
# │   python-dateutil                                    │ https://pypi.org/simple                   │
# │   python-decouple                                    │ https://pypi.org/simple                   │
# │   python-docx                                        │ https://pypi.org/simple                   │
# │   python-dotenv                                      │ https://pypi.org/simple                   │
# │   python-engineio                                    │ https://pypi.org/simple                   │
# │   python-json-logger                                 │ https://pypi.org/simple                   │
# │   python-multipart                                   │ https://pypi.org/simple                   │
# │   python-socketio                                    │ https://pypi.org/simple                   │
# │   python-statemachine                                │ https://pypi.org/simple                   │
# │   pytz                                               │ https://pypi.org/simple                   │
# │   pytz-deprecation-shim                              │ https://pypi.org/simple                   │
# │   pyzmq                                              │ https://pypi.org/simple                   │
# │   pyzstd                                             │ https://pypi.org/simple                   │
# │   qrcode                                             │ https://pypi.org/simple                   │
# │   qtconsole                                          │ https://pypi.org/simple                   │
# │   qudida                                             │ https://pypi.org/simple                   │
# │   quickchart-io                                      │ https://pypi.org/simple                   │
# │   rarfile                                            │ https://pypi.org/simple                   │
# │   regex                                              │ https://pypi.org/simple                   │
# │   requests                                           │ https://pypi.org/simple                   │
# │   requests-oauthlib                                  │ https://pypi.org/simple                   │
# │   retrying                                           │ https://pypi.org/simple                   │
# │   rfc3339-validator                                  │ https://pypi.org/simple                   │
# │   rfc3986                                            │ https://pypi.org/simple                   │
# │   rfc3986-validator                                  │ https://pypi.org/simple                   │
# │   rich                                               │ https://pypi.org/simple                   │
# │   rsa                                                │ https://pypi.org/simple                   │
# │   ruff                                               │ https://pypi.org/simple                   │
# │   s3fs                                               │ https://pypi.org/simple                   │
# │   s3transfer                                         │ https://pypi.org/simple                   │
# │   safetensors                                        │ https://pypi.org/simple                   │
# │   scikit-image                                       │ https://pypi.org/simple                   │
# │   scikit-learn                                       │ https://pypi.org/simple                   │
# │   scipy                                              │ https://pypi.org/simple                   │
# │   seaborn                                            │ https://pypi.org/simple                   │
# │   semver                                             │ https://pypi.org/simple                   │
# │   setuptools                                         │ https://pypi.org/simple                   │
# │   simple-websocket                                   │ https://pypi.org/simple                   │
# │   six                                                │ https://pypi.org/simple                   │
# │   smmap                                              │ https://pypi.org/simple                   │
# │   sniffio                                            │ https://pypi.org/simple                   │
# │   snowballstemmer                                    │ https://pypi.org/simple                   │
# │   sortedcontainers                                   │ https://pypi.org/simple                   │
# │   soupsieve                                          │ https://pypi.org/simple                   │
# │   speaklater                                         │ https://pypi.org/simple                   │
# │   sphinxcontrib-applehelp                            │ https://pypi.org/simple                   │
# │   sphinxcontrib-devhelp                              │ https://pypi.org/simple                   │
# │   sphinxcontrib-htmlhelp                             │ https://pypi.org/simple                   │
# │   sphinxcontrib-jsmath                               │ https://pypi.org/simple                   │
# │   sphinxcontrib-qthelp                               │ https://pypi.org/simple                   │
# │   sphinxcontrib-serializinghtml                      │ https://pypi.org/simple                   │
# │   sse-starlette                                      │ https://pypi.org/simple                   │
# │   sseclient-py                                       │ https://pypi.org/simple                   │
# │   stack-data                                         │ https://pypi.org/simple                   │
# │   starlette                                          │ https://pypi.org/simple                   │
# │   strawberry-graphql                                 │ https://pypi.org/simple                   │
# │   streamlit                                          │ https://pypi.org/simple                   │
# │   streamlit-aggrid                                   │ https://pypi.org/simple                   │
# │   streamlit-authenticator                            │ https://pypi.org/simple                   │
# │   sympy                                              │ https://pypi.org/simple                   │
# │   synapseclient                                      │ https://pypi.org/simple                   │
# │   tabulate                                           │ https://pypi.org/simple                   │
# │   tbb                                                │ https://pypi.org/simple                   │
# │   tblib                                              │ https://pypi.org/simple                   │
# │   tenacity                                           │ https://pypi.org/simple                   │
# │   tensorboard                                        │ https://pypi.org/simple                   │
# │   tensorboard-data-server                            │ https://pypi.org/simple                   │
# │   tensorflow                                         │ https://pypi.org/simple                   │
# │   tensorflow-estimator                               │ https://pypi.org/simple                   │
# │   tensorflow-io-gcs-filesystem                       │ https://pypi.org/simple                   │
# │   termcolor                                          │ https://pypi.org/simple                   │
# │   terminado                                          │ https://pypi.org/simple                   │
# │   texttable                                          │ https://pypi.org/simple                   │
# │   threadpoolctl                                      │ https://pypi.org/simple                   │
# │   tifffile                                           │ https://pypi.org/simple                   │
# │   tinycss2                                           │ https://pypi.org/simple                   │
# │   tk                                                 │ https://pypi.org/simple                   │
# │   tokenizers                                         │ https://pypi.org/simple                   │
# │   toml                                               │ https://pypi.org/simple                   │
# │   tomli                                              │ https://pypi.org/simple                   │
# │   toolz                                              │ https://pypi.org/simple                   │
# │   torch                                              │ https://pypi.org/simple                   │
# │   torchaudio                                         │ https://pypi.org/simple                   │
# │   torchvision                                        │ https://pypi.org/simple                   │
# │   tornado                                            │ https://pypi.org/simple                   │
# │   tqdm                                               │ https://pypi.org/simple                   │
# │   traitlets                                          │ https://pypi.org/simple                   │
# │   transformers                                       │ https://pypi.org/simple                   │
# │   twilio                                             │ https://pypi.org/simple                   │
# │   types-dataclasses                                  │ https://pypi.org/simple                   │
# │   typing-inspect                                     │ https://pypi.org/simple                   │
# │   typing_extensions                                  │ https://pypi.org/simple                   │
# │   tzdata                                             │ https://pypi.org/simple                   │
# │   tzlocal                                            │ https://pypi.org/simple                   │
# │   uc-micro-py                                        │ https://pypi.org/simple                   │
# │   universal-analytics-python3                        │ https://pypi.org/simple                   │
# │   uri-template                                       │ https://pypi.org/simple                   │
# │   urllib3                                            │ https://pypi.org/simple                   │
# │   uvicorn                                            │ https://pypi.org/simple                   │
# │   validators                                         │ https://pypi.org/simple                   │
# │   voluptuous                                         │ https://pypi.org/simple                   │
# │   voxel51-eta                                        │ https://pypi.org/simple                   │
# │   watchdog                                           │ https://pypi.org/simple                   │
# │   wcwidth                                            │ https://pypi.org/simple                   │
# │   webauthn                                           │ https://pypi.org/simple                   │
# │   webcolors                                          │ https://pypi.org/simple                   │
# │   webencodings                                       │ https://pypi.org/simple                   │
# │   websocket-client                                   │ https://pypi.org/simple                   │
# │   websockets                                         │ https://pypi.org/simple                   │
# │   wheel                                              │ https://pypi.org/simple                   │
# │   widgetsnbextension                                 │ https://pypi.org/simple                   │
# │   win32-setctime                                     │ https://pypi.org/simple                   │
# │   wrapt                                              │ https://pypi.org/simple                   │
# │   wsproto                                            │ https://pypi.org/simple                   │
# │   xformers                                           │ https://pypi.org/simple                   │
# │   xmltodict                                          │ https://pypi.org/simple                   │
# │   xyzservices                                        │ https://pypi.org/simple                   │
# │   yarl                                               │ https://pypi.org/simple                   │
# │   yfinance                                           │ https://pypi.org/simple                   │
# │   zict                                               │ https://pypi.org/simple                   │
# │   zipp                                               │ https://pypi.org/simple                   │
# │                                                      ╵                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────── Not Synced with Cluster ─────────────────────────────────────╮
# │                    ╷                                                                 ╷           │
# │   Package          │ Error                                                           │ Risk      │
# │ ╶──────────────────┼─────────────────────────────────────────────────────────────────┼─────────╴ │
# │   vboxapi          │ Failed to convert the package egg to a wheel, will not be       │ Warning   │
# │                    │ included in environment, check stdout for egg conversion log    │           │
# │   tensorflow-intel │ The 'tensorflow-intel' PyPI package is Windows-only, and will   │ Warning   │
# │                    │ not work on a cluster                                           │           │
# │                    │ Install the standard tensorflow version using `pip install      │           │
# │                    │ tensorflow` or `conda install -conda-forge tensorflow`          │           │
# │   opencv-python    │ The 'opencv-python' PyPI package is not portable, and will not  │ Warning   │
# │                    │ work on a cluster                                               │           │
# │                    │ Install opencv-python using `conda install -c conda-forge       │           │
# │                    │ opencv`                                                         │           │
# │   mysqlclient      │ The 'mysqlclient' PyPI package is not portable, and will not    │ Warning   │
# │                    │ work on a cluster                                               │           │
# │                    │ Install mysqlclient using `conda install -c conda-forge         │           │
# │                    │ mysqlclient`                                                    │           │
# │   h5py             │ The 'h5py' PyPI package is not portable, and will not work on a │ Warning   │
# │                    │ cluster                                                         │           │
# │                    │ Install h5py using `conda install -c conda-forge h5py`          │           │
# │                    ╵                                                                 ╵           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# ClusterCreationError                      Traceback (most recent call last)
# File <timed exec>:1
#
# File ~\AppData\Roaming\Python\Python311\site-packages\coiled\_beta\cluster.py:508, in ClusterBeta.__init__(self, name, software, n_workers, worker_class, worker_options, worker_vm_types, worker_cpu, worker_memory, worker_disk_size, worker_gpu, worker_gpu_type, scheduler_class, scheduler_options, scheduler_vm_types, scheduler_cpu, scheduler_memory, scheduler_gpu, asynchronous, cloud, account, shutdown_on_close, use_scheduler_public_ip, use_dashboard_https, credentials, credentials_duration_seconds, timeout, environ, tags, send_dask_config, backend_options, show_widget, configure_logging, wait_for_workers, package_sync, package_sync_strict, package_sync_ignore, package_sync_fail_on, private_to_creator, use_best_zone, compute_purchase_option, scheduler_port, allow_ingress_from, allow_ssh, new_build_backend, jupyter)
#     506     if self.cluster_id:
#     507         log_cluster_debug_info(self.cluster_id, self.account)
# --> 508     raise e.with_traceback(None)
#     509 except KeyboardInterrupt as e:
#     510     error = e
#
# ClusterCreationError: Cluster status is error (reason: Workers all had error -> Software build failed -> Unknown error during env install, we suggest you contact us at support@coiled.io. Full build logs are available here: https://cloud.coiled.io/software/alias/91401/build/84515?account=moco-makers-group&tab=logs ) (cluster_id: 528056)

# %%
futures = client.map(extract, chunked_list)
wait(futures)

# We had one error in one file.  Let's just ignore and move on.
good = [future for future in futures if future.status == "finished"]

lists = client.gather(good)

print(lists)
print("Closing cluster")
cluster.close()
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000021DFBC1A050>
# Unclosed connector
# connections: ['[(<aiohttp.client_proto.ResponseHandler object at 0x0000021DFBC63620>, 78448.5)]']
# connector: <aiohttp.connector.TCPConnector object at 0x0000021DDC5B7590>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 futures = client.map(extract, chunked_list)
#       2 wait(futures)
#       4 # We had one error in one file.  Let's just ignore and move on.
#
# NameError: name 'client' is not defined
